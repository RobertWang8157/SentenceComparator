# %%
import tkinter as tk
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

# Define content_entry as a global variable
content_entry = None

def add_data():
    # Add data to the database based on user input
    subject = selected_subject.get()
    intent_type = selected_intent_type.get()

    # Check if content_entry exists
    if content_entry:
        content = content_entry.get()
    else:
        content = None

    if not content:
        print("Content is missing. Please enter content.")
        return

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, tag, content, active_ind) VALUES (%s, %s, %s, 'Y')"
    data = (subject, intent_type, content)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type WHERE subject_code = %s", (subject,))
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    for widget in radio_frame.winfo_children():
        widget.destroy()

    for intent_type in intent_types:
        tk.Radiobutton(radio_frame, text=intent_type, variable=selected_intent_type, value=intent_type, font=("Helvetica", 14)).pack()

def open_add_frame():
    global selected_subject, selected_intent_type, radio_frame, content_entry

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16))
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create a variable to store the selected subject code
    selected_subject = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14))
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons
    radio_frame = tk.Frame(add_window)
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14))
    show_intent_types_button.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14))
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40)
    content_entry.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14))
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14))
add_button.pack()

# Start the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/johnny/anaconda3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "/var/folders/8s/9fh2s7w53w1fks_4dpp52tyw0000gn/T/ipykernel_6227/1445578185.py", line 74, in open_add_frame
#     cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
#   File "/Users/johnny/anaconda3/lib/python3.10/site-packages/mysql/connector/cursor.py", line 617, in execute
#     self._handle_result(self._connection.cmd_query(stmt))
#   File "/Users/johnny/anaconda3/lib/python3.10/site-packages/mysql/connector/opentelemetry/context_propagation.py", line 77, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "/Users/johnny/anaconda3/lib/python3.10/site-packages/mysql/connector/connection.py", line 1069, in cmd_query
#     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
# ...

# %%
import tkinter as tk
from tkinter import Text, Checkbutton, IntVar
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

# Define content_entry as a global variable
content_entry = None

def add_data():
    # Add data to the database based on user input
    subject_text = subject_entry.get("1.0", "end-1c")  # Retrieve text from Text widget
    object_text = object_entry.get("1.0", "end-1c")  # Retrieve text from Text widget
    intent_type = selected_intent_type.get()
    command_ind = command_var.get()
    public_ind = public_var.get()
    active_ind = active_var.get()

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, object, tag, content, command_ind, public_ind, active_ind) VALUES (%s, %s, %s, %s, %s, %s, %s)"
    data = (subject_text, object_text, intent_type, content_entry.get(), command_ind, public_ind, active_ind)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type WHERE subject_code = %s", (subject,))
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    for widget in radio_frame.winfo_children():
        widget.destroy()

    for intent_type in intent_types:
        tk.Radiobutton(radio_frame, text=intent_type, variable=selected_intent_type, value=intent_type, font=("Helvetica", 14)).pack()

def open_add_frame():
    global selected_subject, selected_intent_type, radio_frame, content_entry, subject_entry, object_entry, command_var, public_var, active_var

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16))
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create a variable to store the selected subject code
    selected_subject = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14))
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons
    radio_frame = tk.Frame(add_window)
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14))
    show_intent_types_button.pack()

    # Create Text widgets for subject and object
    subject_label = tk.Label(add_window, text="Subject:", font=("Helvetica", 14))
    subject_label.pack()
    subject_entry = Text(add_window, height=2, width=40, font=("Helvetica", 12))
    subject_entry.pack()

    object_label = tk.Label(add_window, text="Object:", font=("Helvetica", 14))
    object_label.pack()
    object_entry = Text(add_window, height=2, width=40, font=("Helvetica", 12))
    object_entry.pack()

    # Create Checkbutton widgets for command, public, and active indicators
    command_var = IntVar()
    command_checkbutton = Checkbutton(add_window, text="Command Indicator", variable=command_var, font=("Helvetica", 12))
    command_checkbutton.pack()

    public_var = IntVar()
    public_checkbutton = Checkbutton(add_window, text="Public Indicator", variable=public_var, font=("Helvetica", 12))
    public_checkbutton.pack()

    active_var = IntVar()
    active_checkbutton = Checkbutton(add_window, text="Active Indicator", variable=active_var, font=("Helvetica", 12))
    active_checkbutton.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14))
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40)
    content_entry.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14))
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14))
add_button.pack()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import Text, Checkbutton, IntVar
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

# Define content_entry as a global variable
content_entry = None

def add_data():
    # Add data to the database based on user input
    subject_text = subject_entry.get("1.0", "end-1c")  # Retrieve text from Text widget
    object_text = object_entry.get("1.0", "end-1c")  # Retrieve text from Text widget
    intent_type = selected_intent_type.get()
    command_ind = command_var.get()
    public_ind = public_var.get()
    active_ind = active_var.get()

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, object, tag, content, command_ind, public_ind, active_ind) VALUES (%s, %s, %s, %s, %s, %s, %s)"
    data = (subject_text, object_text, intent_type, content_entry.get(), command_ind, public_ind, active_ind)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type WHERE subject_code = %s", (subject,))
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    for widget in radio_frame.winfo_children():
        widget.destroy()

    for intent_type in intent_types:
        tk.Radiobutton(radio_frame, text=intent_type, variable=selected_intent_type, value=intent_type, font=("Helvetica", 14), bg='#333', fg='#FFF').pack()

def open_add_frame():
    global selected_subject, selected_intent_type, radio_frame, content_entry, subject_entry, object_entry, command_var, public_var, active_var

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")
    add_window.configure(bg='#333')

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16), bg='#333', fg='#FFF')
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create a variable to store the selected subject code
    selected_subject = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14), bg='#333', fg='#FFF')
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.config(bg='#333', fg='#FFF')
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons
    radio_frame = tk.Frame(add_window, bg='#333')
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14), bg='#555', fg='#FFF')
    show_intent_types_button.pack()

    # Create Text widgets for subject and object
    subject_label = tk.Label(add_window, text="Subject:", font=("Helvetica", 14), bg='#333', fg='#FFF')
    subject_label.pack()
    subject_entry = Text(add_window, height=2, width=40, font=("Helvetica", 12), bg='#555', fg='#FFF')
    subject_entry.pack()

    object_label = tk.Label(add_window, text="Object:", font=("Helvetica", 14), bg='#333', fg='#FFF')
    object_label.pack()
    object_entry = Text(add_window, height=2, width=40, font=("Helvetica", 12), bg='#555', fg='#FFF')
    object_entry.pack()

    # Create Checkbutton widgets for command, public, and active indicators
    command_var = IntVar()
    command_checkbutton = Checkbutton(add_window, text="Command Indicator", variable=command_var, font=("Helvetica", 12), bg='#333', fg='#FFF')
    command_checkbutton.pack()

    public_var = IntVar()
    public_checkbutton = Checkbutton(add_window, text="Public Indicator", variable=public_var, font=("Helvetica", 12), bg='#333', fg='#FFF')
    public_checkbutton.pack()

    active_var = IntVar()
    active_checkbutton = Checkbutton(add_window, text="Active Indicator", variable=active_var, font=("Helvetica", 12), bg='#333', fg='#FFF')
    active_checkbutton.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14), bg='#333', fg='#FFF')
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40, bg='#555', fg='#FFF')
    content_entry.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14), bg='#555', fg='#FFF')
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")
root.configure(bg='#333')

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14), bg='#555', fg='#FFF')
add_button.pack()

# Start the main event loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 176
#     173 add_button.pack()
#     175 # Start the main event loop
# --> 176 root.mainloop()
#
# File ~/anaconda3/lib/python3.10/tkinter/__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

# Define content_entry, command_checkbox, and public_checkbox as global variables
content_entry = None
command_checkbox = None
public_checkbox = None

def add_data():
    # Add data to the database based on user input
    subject = selected_subject.get()
    intent_type = selected_intent_type.get()
    object_type = selected_object_type.get()

    # Check if content_entry exists
    if content_entry:
        content = content_entry.get()
    else:
        content = None

    # Check if checkboxes are selected
    command_ind = 'Y' if command_checkbox.get() else 'N'
    public_ind = 'Y' if public_checkbox.get() else 'N'

    if not content:
        print("Content is missing. Please enter content.")
        return

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, object, tag, content, command_ind, public_ind, active_ind) VALUES (%s, %s, %s, %s, %s, %s, 'Y')"
    data = (subject, object_type, intent_type, content, command_ind, public_ind)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

    # Show confirmation message for 2 seconds
    confirmation_label.config(text="Data saved successfully!")
    root.after(2000, clear_confirmation_message)

def clear_confirmation_message():
    # Clear the confirmation message
    confirmation_label.config(text="")

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type WHERE subject_code = %s", (subject,))
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    for widget in radio_frame.winfo_children():
        widget.destroy()

    for intent_type in intent_types:
        tk.Radiobutton(radio_frame, text=intent_type, variable=selected_intent_type, value=intent_type, font=("Helvetica", 14)).pack()

def open_add_frame():
    global selected_subject, selected_intent_type, selected_object_type, radio_frame, content_entry, command_checkbox, public_checkbox, confirmation_label

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16))
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create variables to store the selected subject code and object type
    selected_subject = tk.StringVar()
    selected_object_type = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14))
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons
    radio_frame = tk.Frame(add_window)
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a label and dropdown menu to select an object type
    object_label = tk.Label(add_window, text="Select Object Type:", font=("Helvetica", 14))
    object_label.pack()
    object_dropdown = tk.OptionMenu(add_window, selected_object_type, *subject_codes)
    object_dropdown.pack()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14))
    show_intent_types_button.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14))
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40)
    content_entry.pack()

    # Create checkboxes for command_ind and public_ind
    command_checkbox = tk.BooleanVar()
    public_checkbox = tk.BooleanVar()

    command_checkbox_label = tk.Checkbutton(add_window, text="Command Indicator", variable=command_checkbox, font=("Helvetica", 14))
    command_checkbox_label.pack()

    public_checkbox_label = tk.Checkbutton(add_window, text="Public Indicator", variable=public_checkbox, font=("Helvetica", 14))
    public_checkbox_label.pack()

    # Create a label for displaying confirmation message
    confirmation_label = tk.Label(add_window, text="", font=("Helvetica", 14), fg="green")
    confirmation_label.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14))
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14))
add_button.pack()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type WHERE subject_code = %s", (subject,))
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    for widget in radio_frame.winfo_children():
        widget.destroy()

    # Create a scrollbar for the radio_frame
    scrollbar = tk.Scrollbar(radio_frame)
    scrollbar.pack(side=tk.RIGHT, fill=tk.Y)

    # Create a listbox to hold the Radiobuttons with the scrollbar
    listbox = tk.Listbox(radio_frame, yscrollcommand=scrollbar.set, selectmode=tk.SINGLE, font=("Helvetica", 14))
    listbox.pack(expand=True, fill=tk.BOTH)

    for intent_type in intent_types:
        listbox.insert(tk.END, intent_type)

    scrollbar.config(command=listbox.yview)

    selected_intent_type.set(intent_types[0] if intent_types else "")

def add_data():
    # Add data to the database based on user input
    subject = selected_subject.get()
    intent_type = selected_intent_type.get()
    object_type = selected_object_type.get()

    # Check if content_entry exists
    if content_entry:
        content = content_entry.get()
    else:
        content = None

    # Check if checkboxes are selected
    command_ind = 'Y' if command_checkbox.get() else 'N'
    public_ind = 'Y' if public_checkbox.get() else 'N'

    if not content:
        print("Content is missing. Please enter content.")
        return

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, object, tag, content, command_ind, public_ind, active_ind) VALUES (%s, %s, %s, %s, %s, %s, 'Y')"
    data = (subject, object_type, intent_type, content, command_ind, public_ind)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

    # Show confirmation message for 2 seconds
    confirmation_label.config(text="Data saved successfully!")
    root.after(2000, clear_confirmation_message)

def clear_confirmation_message():
    # Clear the confirmation message
    confirmation_label.config(text="")

def open_add_frame():
    global selected_subject, selected_intent_type, selected_object_type, content_entry, command_checkbox, public_checkbox, confirmation_label, radio_frame

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16))
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create variables to store the selected subject code and object type
    selected_subject = tk.StringVar()
    selected_object_type = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14))
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons (no need for global radio_frame)
    radio_frame = tk.Frame(add_window)
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a label and dropdown menu to select an object type
    object_label = tk.Label(add_window, text="Select Object Type:", font=("Helvetica", 14))
    object_label.pack()
    object_dropdown = tk.OptionMenu(add_window, selected_object_type, *subject_codes)
    object_dropdown.pack()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14))
    show_intent_types_button.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14))
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40)
    content_entry.pack()

    # Create checkboxes for command_ind and public_ind
    command_checkbox = tk.BooleanVar()
    public_checkbox = tk.BooleanVar()

    command_checkbox_label = tk.Checkbutton(add_window, text="Command Indicator", variable=command_checkbox, font=("Helvetica", 14))
    command_checkbox_label.pack()

    public_checkbox_label = tk.Checkbutton(add_window, text="Public Indicator", variable=public_checkbox, font=("Helvetica", 14))
    public_checkbox_label.pack()

    # Create a label for displaying confirmation message
    confirmation_label = tk.Label(add_window, text="", font=("Helvetica", 14), fg="green")
    confirmation_label.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14))
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14))
add_button.pack()

# Start the main event loop
root.mainloop()
# Out:
# 2023-12-18 11:00:02.180 python[47366:204126] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit

# %%
import tkinter as tk
from tkinter import ttk
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

# Define content_entry, command_checkbox, and public_checkbox as global variables
content_entry = None
command_checkbox = None
public_checkbox = None

def add_data():
    # Add data to the database based on user input
    subject = selected_subject.get()
    intent_type = selected_intent_type.get()
    object_type = selected_object_type.get()

    # Check if content_entry exists
    if content_entry:
        content = content_entry.get()
    else:
        content = None

    # Check if checkboxes are selected
    command_ind = 'Y' if command_checkbox.get() else 'N'
    public_ind = 'Y' if public_checkbox.get() else 'N'

    if not content:
        print("Content is missing. Please enter content.")
        return

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, object, tag, content, command_ind, public_ind, active_ind) VALUES (%s, %s, %s, %s, %s, %s, 'Y')"
    data = (subject, object_type, intent_type, content, command_ind, public_ind)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

    # Show confirmation message for 2 seconds
    confirmation_label.config(text="Data saved successfully!")
    root.after(2000, clear_confirmation_message)

def clear_confirmation_message():
    # Clear the confirmation message
    confirmation_label.config(text="")

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type WHERE subject_code = %s", (subject,))
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Clear the existing frame
    for widget in radio_frame.winfo_children():
        widget.destroy()

    # Create a scrollable frame for radio buttons
    scrollable_frame = tk.Frame(radio_frame)
    scrollable_frame.pack(side=tk.LEFT, fill=tk.Y)

    # Create a canvas to hold the frame and add a scrollbar
    canvas = tk.Canvas(scrollable_frame, height=150)  # Set the height as needed
    scrollbar = tk.Scrollbar(scrollable_frame, command=canvas.yview)
    canvas.pack(side=tk.LEFT, fill=tk.Y)
    scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
    canvas.configure(yscrollcommand=scrollbar.set)

    # Create a frame to hold radio buttons inside the canvas
    inner_frame = tk.Frame(canvas)
    canvas.create_window((0, 0), window=inner_frame, anchor=tk.NW)

    # Create radio buttons in the inner frame
    for intent_type in intent_types:
        tk.Radiobutton(inner_frame, text=intent_type, variable=selected_intent_type, value=intent_type, font=("Helvetica", 14)).pack()

    # Update the scroll region of the canvas
    inner_frame.update_idletasks()
    canvas.config(scrollregion=canvas.bbox("all"))

def open_add_frame():
    global selected_subject, selected_intent_type, selected_object_type, radio_frame, content_entry, command_checkbox, public_checkbox, confirmation_label

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16))
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT DISTINCT subject_code FROM intent_type")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create variables to store the selected subject code and object type
    selected_subject = tk.StringVar()
    selected_object_type = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14))
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons
    radio_frame = tk.Frame(add_window)
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a label and dropdown menu to select an object type
    object_label = tk.Label(add_window, text="Select Object Type:", font=("Helvetica", 14))
    object_label.pack()
    object_dropdown = tk.OptionMenu(add_window, selected_object_type, *subject_codes)
    object_dropdown.pack()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14))
    show_intent_types_button.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14))
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40)
    content_entry.pack()

    # Create checkboxes for command_ind and public_ind
    command_checkbox = tk.BooleanVar()
    public_checkbox = tk.BooleanVar()

    command_checkbox_label = tk.Checkbutton(add_window, text="Command Indicator", variable=command_checkbox, font=("Helvetica", 14))
    command_checkbox_label.pack()

    public_checkbox_label = tk.Checkbutton(add_window, text="Public Indicator", variable=public_checkbox, font=("Helvetica", 14))
    public_checkbox_label.pack()

    # Create a label for displaying confirmation message
    confirmation_label = tk.Label(add_window, text="", font=("Helvetica", 14), fg="green")
    confirmation_label.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14))
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14))
add_button.pack()

# Start the main event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import mysql.connector

def connect_to_database():
    # Modify the database connection details as needed
    connection = mysql.connector.connect(
        host="localhost",
        user="root",
        password="3659215fF",
        database="handle_together"
    )
    return connection

# Define content_entry, command_checkbox, and public_checkbox as global variables
content_entry = None
command_checkbox = None
public_checkbox = None

def add_data():
    # Add data to the database based on user input
    subject = selected_subject.get()
    intent_type = selected_intent_type.get()
    object_type = selected_object_type.get()

    # Check if content_entry exists
    if content_entry:
        content = content_entry.get()
    else:
        content = None

    # Check if checkboxes are selected
    command_ind = 'Y' if command_checkbox.get() else 'N'
    public_ind = 'Y' if public_checkbox.get() else 'N'

    if not content:
        print("Content is missing. Please enter content.")
        return

    connection = connect_to_database()
    cursor = connection.cursor()

    # Insert the data into the intent_training_data table
    query = "INSERT INTO intent_training_data (subject, object, tag, content, command_ind, public_ind, active_ind) VALUES (%s, %s, %s, %s, %s, %s, 'Y')"
    data = (subject, object_type, intent_type, content, command_ind, public_ind)

    cursor.execute(query, data)
    connection.commit()

    cursor.close()
    connection.close()

    # Show confirmation message for 2 seconds
    confirmation_label.config(text="Data saved successfully!")
    root.after(2000, clear_confirmation_message)

def clear_confirmation_message():
    # Clear the confirmation message
    confirmation_label.config(text="")

def update_radio_buttons():
    # Update radio buttons based on the selected subject
    subject = selected_subject.get()
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT intent_type FROM intent_type")
    intent_types = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Clear the existing frame
    for widget in radio_frame.winfo_children():
        widget.destroy()

    # Create a scrollable frame for radio buttons
    scrollable_frame = tk.Frame(radio_frame)
    scrollable_frame.pack(side=tk.LEFT, fill=tk.Y)

    # Create a canvas to hold the frame and add a scrollbar
    canvas = tk.Canvas(scrollable_frame, height=150)  # Set the height as needed
    scrollbar = tk.Scrollbar(scrollable_frame, command=canvas.yview)
    canvas.pack(side=tk.LEFT, fill=tk.Y)
    scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
    canvas.configure(yscrollcommand=scrollbar.set)

    # Create a frame to hold radio buttons inside the canvas
    inner_frame = tk.Frame(canvas)
    canvas.create_window((0, 0), window=inner_frame, anchor=tk.NW)

    # Create radio buttons in the inner frame
    for intent_type in intent_types:
        tk.Radiobutton(inner_frame, text=intent_type, variable=selected_intent_type, value=intent_type, font=("Helvetica", 14)).pack()

    # Update the scroll region of the canvas
    inner_frame.update_idletasks()
    canvas.config(scrollregion=canvas.bbox("all"))

def open_add_frame():
    global selected_subject, selected_intent_type, selected_object_type, radio_frame, content_entry, command_checkbox, public_checkbox, confirmation_label

    add_window = tk.Toplevel(root)
    add_window.title("Add Data")

    # Create and configure widgets for the Add Data frame
    add_label = tk.Label(add_window, text="Add Data", font=("Helvetica", 16))
    add_label.pack()

    # Fetch distinct subject codes from intent_type table
    connection = connect_to_database()
    cursor = connection.cursor()
    cursor.execute("SELECT distinct subject FROM intent_training_data union SELECT distinct object subject FROM intent_training_data")
    subject_codes = [row[0] for row in cursor.fetchall()]
    cursor.close()
    connection.close()

    # Create variables to store the selected subject code and object type
    selected_subject = tk.StringVar()
    selected_object_type = tk.StringVar()

    # Create a label and dropdown menu to select a subject code
    subject_label = tk.Label(add_window, text="Select Subject Code:", font=("Helvetica", 14))
    subject_label.pack()
    subject_dropdown = tk.OptionMenu(add_window, selected_subject, *subject_codes)
    subject_dropdown.pack()

    # Create a frame to hold the radio buttons
    radio_frame = tk.Frame(add_window)
    radio_frame.pack()

    # Create a variable to store the selected intent type
    selected_intent_type = tk.StringVar()

    # Create a label and dropdown menu to select an object type
    object_label = tk.Label(add_window, text="Select Object Type:", font=("Helvetica", 14))
    object_label.pack()
    object_dropdown = tk.OptionMenu(add_window, selected_object_type, *subject_codes)
    object_dropdown.pack()

    # Create a button to fetch and show intent types based on the selected subject code
    show_intent_types_button = tk.Button(add_window, text="Show Intent Types", command=update_radio_buttons, font=("Helvetica", 14))
    show_intent_types_button.pack()

    # Create an entry for content with a larger size and font
    content_label = tk.Label(add_window, text="Content:", font=("Helvetica", 14))
    content_label.pack()
    content_entry = tk.Entry(add_window, font=("Helvetica", 16), width=40)
    content_entry.pack()

    # Create checkboxes for command_ind and public_ind
    command_checkbox = tk.BooleanVar()
    public_checkbox = tk.BooleanVar()

    command_checkbox_label = tk.Checkbutton(add_window, text="Command Indicator", variable=command_checkbox, font=("Helvetica", 14))
    command_checkbox_label.pack()

    public_checkbox_label = tk.Checkbutton(add_window, text="Public Indicator", variable=public_checkbox, font=("Helvetica", 14))
    public_checkbox_label.pack()

    # Create a label for displaying confirmation message
    confirmation_label = tk.Label(add_window, text="", font=("Helvetica", 14), fg="green")
    confirmation_label.pack()

    # Create a button to save the data
    save_button = tk.Button(add_window, text="Save", command=add_data, font=("Helvetica", 14))
    save_button.pack()

# Initialize the main application window
root = tk.Tk()
root.title("Data Management")

# Create a button to open the "Add Data" frame
add_button = tk.Button(root, text="Add", command=open_add_frame, font=("Helvetica", 14))
add_button.pack()

# Start the main event loop
root.mainloop()
# Out:
# 2024-04-17 14:33:58.095 python[84919:946604] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
